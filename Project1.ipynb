# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("WDI_csv/WDIData.csv")
data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05   NaN
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05   NaN
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965     ...            2008       2009       2010  \
# 0   NaN   NaN   NaN   NaN   NaN     ...             NaN        NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN     ...             NaN        NaN        NaN
# 2   NaN   NaN   NaN   NaN   NaN     ...       82.831932  83.474617  84.006076
# ...

# %%
temp = data[data["Country Code"] == "ARB"]
temp.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05   NaN
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05   NaN
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965     ...            2008       2009       2010  \
# 0   NaN   NaN   NaN   NaN   NaN     ...             NaN        NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN     ...             NaN        NaN        NaN
# 2   NaN   NaN   NaN   NaN   NaN     ...       82.831932  83.474617  84.006076
# ...

# %%
test = temp[data["Indicator Name"].str.contains("urban population")]
# Out:
# /Users/ericxia/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
brazil = data[data["Country Name"] == "Brazil"]
brazil.head()
# Out:
#        Country Name Country Code  \
# 113077       Brazil          BRA
# 113078       Brazil          BRA
# 113079       Brazil          BRA
# 113080       Brazil          BRA
# 113081       Brazil          BRA
#
#                                            Indicator Name     Indicator Code  \
# 113077  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05
# 113078  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05
# 113079  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 113080            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 113081  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#         1960  1961  1962  1963  1964  1965     ...            2008       2009  \
# 113077   NaN   NaN   NaN   NaN   NaN   NaN     ...             NaN        NaN
# 113078   NaN   NaN   NaN   NaN   NaN   NaN     ...             NaN        NaN
# ...

# %%
brazil = brazil.set_index("Indicator Name")
brazil.head()
# Out:
#                                                    Country Name Country Code  \
# Indicator Name
# 2005 PPP conversion factor, GDP (LCU per intern...       Brazil          BRA
# 2005 PPP conversion factor, private consumption...       Brazil          BRA
# Access to clean fuels and technologies for cook...       Brazil          BRA
# Access to electricity (% of population)                  Brazil          BRA
# Access to electricity, rural (% of rural popula...       Brazil          BRA
#
#                                                        Indicator Code  1960  \
# Indicator Name
# 2005 PPP conversion factor, GDP (LCU per intern...      PA.NUS.PPP.05   NaN
# 2005 PPP conversion factor, private consumption...  PA.NUS.PRVT.PP.05   NaN
# Access to clean fuels and technologies for cook...     EG.CFT.ACCS.ZS   NaN
# Access to electricity (% of population)                EG.ELC.ACCS.ZS   NaN
# Access to electricity, rural (% of rural popula...  EG.ELC.ACCS.RU.ZS   NaN
#
# ...

# %%
brazil = brazil.loc[:, "1990":"2016"]
brazil.head()
# Out:
#                                                          1990       1991  \
# Indicator Name
# 2005 PPP conversion factor, GDP (LCU per intern...        NaN        NaN
# 2005 PPP conversion factor, private consumption...        NaN        NaN
# Access to clean fuels and technologies for cook...        NaN        NaN
# Access to electricity (% of population)             87.475116  89.681335
# Access to electricity, rural (% of rural popula...  55.415374  56.666515
#
#                                                          1992       1993  \
# Indicator Name
# 2005 PPP conversion factor, GDP (LCU per intern...        NaN        NaN
# 2005 PPP conversion factor, private consumption...        NaN        NaN
# Access to clean fuels and technologies for cook...        NaN        NaN
# Access to electricity (% of population)             88.803833  89.999927
# Access to electricity, rural (% of rural popula...  54.332727  57.204498
#
# ...

# %%
brazil = brazil.dropna(how = "all")
brazil.head()
# Out:
#                                                          1990       1991  \
# Indicator Name
# 2005 PPP conversion factor, GDP (LCU per intern...        NaN        NaN
# 2005 PPP conversion factor, private consumption...        NaN        NaN
# Access to clean fuels and technologies for cook...        NaN        NaN
# Access to electricity (% of population)             87.475116  89.681335
# Access to electricity, rural (% of rural popula...  55.415374  56.666515
#
#                                                          1992       1993  \
# Indicator Name
# 2005 PPP conversion factor, GDP (LCU per intern...        NaN        NaN
# 2005 PPP conversion factor, private consumption...        NaN        NaN
# Access to clean fuels and technologies for cook...        NaN        NaN
# Access to electricity (% of population)             88.803833  89.999927
# Access to electricity, rural (% of rural popula...  54.332727  57.204498
#
# ...

# %%
educ_brazil = brazil[brazil.index.str.contains("School enrollment")]
educ_brazil.head()
# Out:
#                                                  1990  1991  1992  1993  1994  \
# Indicator Name
# School enrollment, preprimary (% gross)           NaN   NaN   NaN   NaN   NaN
# School enrollment, preprimary, female (% gross)   NaN   NaN   NaN   NaN   NaN
# School enrollment, preprimary, male (% gross)     NaN   NaN   NaN   NaN   NaN
# School enrollment, primary (% gross)              NaN   NaN   NaN   NaN   NaN
# School enrollment, primary (% net)                NaN   NaN   NaN   NaN   NaN
#
#                                                  1995  1996  1997  1998  \
# Indicator Name
# School enrollment, preprimary (% gross)           NaN   NaN   NaN   NaN
# School enrollment, preprimary, female (% gross)   NaN   NaN   NaN   NaN
# School enrollment, preprimary, male (% gross)     NaN   NaN   NaN   NaN
# School enrollment, primary (% gross)              NaN   NaN   NaN   NaN
# School enrollment, primary (% net)                NaN   NaN   NaN   NaN
#
# ...

# %%
educ_brazil = educ_brazil.loc[:, "2000":]
educ_brazil.head()
# Out:
#                                                  2000        2001        2002  \
# Indicator Name
# School enrollment, preprimary (% gross)           NaN         NaN         NaN
# School enrollment, preprimary, female (% gross)   NaN         NaN         NaN
# School enrollment, preprimary, male (% gross)     NaN         NaN         NaN
# School enrollment, primary (% gross)              NaN  150.785553  146.827789
# School enrollment, primary (% net)                NaN   98.033852   95.730492
#
#                                                        2003        2004  \
# Indicator Name
# School enrollment, preprimary (% gross)                 NaN         NaN
# School enrollment, preprimary, female (% gross)         NaN         NaN
# School enrollment, preprimary, male (% gross)           NaN         NaN
# School enrollment, primary (% gross)             140.544495  133.696304
# School enrollment, primary (% net)                93.179619   94.423340
#
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(educ_brazil.loc["School enrollment, tertiary, female (% gross)", :])
ax.set_xlabel("Year")
ax.set_ylabel("Gross % of Female Enrollment in Tertiary Educ")
ax.set_title("Female Enrollment in Higher Education over the Years")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(educ_brazil.loc["School enrollment, tertiary, male (% gross)", :], label = "Males")
plt.plot(educ_brazil.loc["School enrollment, tertiary, female (% gross)", :], label = "Females")
ax.set_xlabel("Year")
ax.set_ylabel("Gross % of Enrollment in Tertiary Educ")
ax.set_title("Enrollment in Higher Education over the Years")
ax.legend()
plt.show()

# %%
brazil_energy = brazil[brazil.index.str.contains("Access to")]
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(brazil_energy.loc["Access to electricity (% of population)",:], label = "Overall")
plt.plot(brazil_energy.loc["Access to electricity, rural (% of rural population)", :], label = "Rural")
ax.set_xlabel("Year")
ax.set_ylabel("Percentage of Households")
ax.set_title("Electricity Access over the Years")
ax.legend()
plt.show()

# %%
brazil_economy = brazil[brazil.index.str.contains("GDP")]

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(brazil_economy.loc["Tax revenue (% of GDP)", :], label = "Tax")
plt.plot(brazil_economy.loc["Trade (% of GDP)", :], label = "Trade")
plt.plot(brazil_economy.loc["Stocks traded, total value (% of GDP)", :], label = "Stocks")
ax.legend()
ax.set_xlabel("Year")
ax.set_ylabel("Percent of GDP")
ax.set_title("Brazil's Economy")
plt.show()

# %%
brazil_city = brazil[brazil.index.str.contains("Urban population")]

# %%
brazil_pov = brazil[brazil.index.str.contains("poverty")]

# %%
world_electricity = data[data["Indicator Name"].str.contains("Access to electricity")]
world_electricity = world_electricity[world_electricity["Indicator Name"].str.contains("rural population")]
world_electricity.dropna(how = "all")
# Out:
#                                              Country Name Country Code  \
# 4                                              Arab World          ARB
# 1553                               Caribbean small states          CSS
# 3102                       Central Europe and the Baltics          CEB
# 4651                           Early-demographic dividend          EAR
# 6200                                  East Asia & Pacific          EAS
# 7749          East Asia & Pacific (excluding high income)          EAP
# 9298           East Asia & Pacific (IDA & IBRD countries)          TEA
# 10847                                           Euro area          EMU
# 12396                               Europe & Central Asia          ECS
# 13945       Europe & Central Asia (excluding high income)          ECA
# 15494        Europe & Central Asia (IDA & IBRD countries)          TEC
# 17043                                      European Union          EUU
# ...

# %%
world_electricity = world_electricity.set_index("Country Name")
world_electricity = world_electricity.loc[:, "1990":"2014"]

# %%
world_electricity = world_electricity.transpose().dropna(how = "all")

# %%
world_stocks = data[data["Indicator Name"].str.contains("Stocks traded, total value")]
world_stocks = world_stocks[world_stocks["Indicator Name"].str.contains("GDP")]
world_stocks = world_stocks.dropna(how = "all")
world_stocks = world_stocks.set_index("Country Name").loc[:, "1990":"2014"]
world_stocks = world_stocks.transpose().dropna(how = "all")

# %%
world_trade = data[data["Indicator Name"].str.contains("Trade \(")]
world_trade = world_trade.set_index("Country Name").loc[:, "1990" : "2014"].transpose()

# %%
world_tax = data[data["Indicator Name"].str.contains("Tax revenue \(%")]
world_tax = world_tax.set_index("Country Name").loc[:, "1990":"2014"].transpose()

# %%
array_stocks = np.asarray(world_stocks).reshape(-1)
array_electricity = np.asarray(world_electricity).reshape(-1)
array_trade = np.asarray(world_trade).reshape(-1)
array_tax = np.asarray(world_tax).reshape(-1)

# %%
keep = ~np.isnan(array_stocks)
array_stocks = array_stocks[keep]
array_electricity = array_electricity[keep]
array_trade = array_trade[keep]
array_tax = array_tax[keep]

keep = ~np.isnan(array_electricity)
array_stocks = array_stocks[keep]
array_electricity = array_electricity[keep]
array_trade = array_trade[keep]
array_tax = array_tax[keep]

keep = ~np.isnan(array_trade)
array_stocks = array_stocks[keep]
array_electricity = array_electricity[keep]
array_trade = array_trade[keep]
array_tax = array_tax[keep]

keep = ~np.isnan(array_tax)
array_stocks = array_stocks[keep]
array_electricity = array_electricity[keep]
array_trade = array_trade[keep]
array_tax = array_tax[keep]

# %%
data = np.array([array_stocks, array_trade, array_tax])
data = data.T

# %%
X = sm.add_constant(data)
model = sm.OLS(array_electricity, X)
results = model.fit()
results.params
# Out:
# array([  6.94037033e+01,   1.34006545e-01,   6.85174038e-02,
#          4.04056442e-01])

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.100
# Model:                            OLS   Adj. R-squared:                  0.098
# Method:                 Least Squares   F-statistic:                     67.90
# Date:                Tue, 03 Oct 2017   Prob (F-statistic):           1.21e-41
# Time:                        21:17:00   Log-Likelihood:                -8398.2
# No. Observations:                1844   AIC:                         1.680e+04
# Df Residuals:                    1840   BIC:                         1.683e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         69.4037      1.645     42.182      0.000      66.177      72.631
# ...
